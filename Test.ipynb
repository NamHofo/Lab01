# %%
import pandas as pd 

data = pd.read_json("/home/hofonam/Documents/UniGap/Project02/data/products_1.json")
data.head(10)
# Out:
#           id                                               name  \
# 0    1391347  Tranh xếp Hình Tia Sáng  Gương Thu Tia Sáng (2...
# 1   74897599  Bộ đồ chơi lắp ghép xe xúc KAVY nhiều màu sắc ...
# 2  154155413  Bộ đồ chơi tàu hỏa, Đồ chơi xe lửa có đường ra...
# 3  253117062  Mô Hình Minifigures Lắp Ráp Nhân Vật Hoạt Hình...
# 4  130978358  Bộ đồ chơi Heo Peppa leo thang - Có nhạc và đè...
# 5  214009046  Đồ Chơi Lắp Ráp LEGO Technic Xe Tải Công Trình...
# 6  171618108  Đồ Chơi LEGO Rượt Đuổi Khủng Long Atrociraptor...
# 7  179970479  Đồ chơi lắp ráp siêu nhân biến hình 3 Robot (ả...
# 8  139457837      Hộp xe tăng pin đèn, WH-3041 (Hộp) - SP353476
# 9  197334787  Đồ Chơi Duka Robot Biến Hình - Chiến Đấu Cơ DK...
#
#                                              url_key   price  \
# 0  tranh-xep-hinh-tia-sang-guong-thu-tia-sang-203...  245700
# 1  bo-do-choi-lap-ghep-xe-xuc-kavy-nhieu-mau-sac-...   87000
# 2  bo-do-choi-tau-hoa-do-choi-xe-lua-co-duong-ray...   59000
# ...
